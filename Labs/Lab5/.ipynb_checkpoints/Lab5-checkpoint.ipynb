# %% [markdown]
# # Phys 330 – Electronics – Lab 5

# %%
import numpy as np
from IPython.display import Image
from decimal import Decimal
from math import pi

# %%
Image("pic1.png")

# %% [markdown]
# I found I needed to offset the wave by approximately 177 degrees to have them on top of eachother prior to sync.

# %%
Image("pic2.png")

# %%
Image("pic3.png")

# %%
Image("pic4.png")

# %% [markdown]
# Above is the generated wave I will be using to produce a sine wave with a differential voltage of 10V

# %%
Image("pic5.png")

# %% [markdown]
# I am not using the above diodes I have opted to use the 1N4001 Diodes simply because I like the way they look on pictures more. It is a little easier to see anode v.s cathode. I expect to get a constant reoccuring "wave" that jumps up. the maximum amplitude should aso be 2 voltage threshodds lower than my input voltage.

# %%
Image("pic7.png")

# %%
Image("pic6.png")

# %%
Image("pic13.png")

# %%
V = 4.0872
R = 2200
Hz = 60
C = 47*10**(-6)

assumption = (V/R)/(2*Hz*C)
print(assumption, "is greater than our found change in voltage of .2777 V")
# Out:
# 0.32940038684719536 is greater than our found change in voltage of .2777 V

# %% [markdown]
# This means the expected ripple is as far in this one case higher than the true voltage ripple.

# %%
Image("pic8.png")

# %%
R = V/0.004
print(R)
C = (V/R)/(2*Hz*.333)
print(C)
# Out:
# 1021.8000000000001
# 0.0001001001001001001

# %% [markdown]
# Using the same equation I had before I need a resistor of roughly 1k Ohm and a 100$\mu$ Farad Cap

# %%
Image("pic14.png")

# %% [markdown]
# This once again gave us a calculated ripple higher than our found ripple. This makes me believe all cases may lead to the true ripple being lower than the predicted outcome. In which case if I wanted to get a 4mA current and a 333mV peak ripple I might try 800 Ohms and maybe an 80$\mu$ Farad Ca. droping both of them by 20% should give me a scalable equation and the true value could be found between those numbers.

# %%
Image("pic9.png")

# %% [markdown]
# I think the amplitude will just be lower on the high end because the resistor will be engaged otherwise it'll just be a sine wave

# %%
Image("pic10.png")

# %% [markdown]
# I think this will be a lot like the previous but maybe lower because the total resistance will be higher when the diode is conducting.

# %%
R1 = 1000
R2 = 2200
R3 = 1000
VTHD = 5*((R1*R3)/(R1+R3))/(R2 + ((R1*R3)/(R1+R3)))
ZS = ((R2*R3)/(R2+R3))/(R1 + ((R2*R3)/(R2+R3)))
print(VTHD,ZS)
# Out:
# 0.9259259259259259 0.4074074074074074

# %%
Image("pic11.png")

# %% [markdown]
# Capacitors just offset the wave so I think it will be a lot like the other wave but the peak will move over.

# %%
Image("Clamp+cap.png")

# %% [markdown]
# A 10 does not fully flatten out my 60 Hz wave but a 100 micro F does

# %%
Image("pic12.png")
