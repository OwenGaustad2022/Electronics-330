# %% [markdown]
# # Lab 6

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import Image
from decimal import Decimal
from math import pi

# %%
Image("Equipment.png")

# %%
Image("Part1.png")

# %% [markdown]
# Transistors pulled were 2N3904 and 2N3906

# %% [markdown]
# 2N3904 is a NPN resistor
#
# Emitter is 718mV collector is 721mV
#
# 2N3906 is a PNP resistor
#
# Emitter is 712mV collector is 706mV

# %%
Image("Part2.png")

# %% [markdown]
# My Z Impedance is 8.42k Ohms

# %% [markdown]
# I did not finish that question in the homework because I had no clue what I was doing but hey I worked the problem backwads and dropped my pot to 270 and yes I was getting half the total Voltage amplitude. But this one did not cut out the underneath and it was a flat top. It looked like the jumping voltage I had before is the top of the voltage that was cutoff. If that dosn't make sense to you Oh well.

# %% [markdown]
# Maybe you ahve a low source and need to amplify with what you have. Or maybe you have critical components proir to this and now you gotta beef that boy up.

# %%
Image("Input_Z.png")

# %%
Z_in = 8420
Z_E = 54.6
Beta = (Z_in/Z_E)-1
print("{:.0F}".format(Decimal(Beta)))
# Out:
# 153

# %%
Image("Output_Z.png")

# %%
V_out = 1.282
V_in = 1.352
R = 1000

Z = ((V_in*R)/(V_out))-R
Z
# Out:
# 54.60218408736341

# %%
Image("Part3.png")

# %%
Image("report.png")
